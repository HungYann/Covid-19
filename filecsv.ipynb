# %%
import pandas as pd

# %%
data = pd.read_csv("countries-aggregated.csv")

# %%
data.head()
# Out:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0        0.0       0
# 1  2020-01-22      Albania          0        0.0       0
# 2  2020-01-22      Algeria          0        0.0       0
# 3  2020-01-22      Andorra          0        0.0       0
# 4  2020-01-22       Angola          0        0.0       0

# %%
data[data.Country=="US"].replace("US","USA")
# Out:
#              Date Country  Confirmed  Recovered  Deaths
# 164    2020-01-22     USA          1        0.0       0
# 340    2020-01-23     USA          1        0.0       0
# 516    2020-01-24     USA          2        0.0       0
# 692    2020-01-25     USA          2        0.0       0
# 868    2020-01-26     USA          5        0.0       0
# 1044   2020-01-27     USA          5        0.0       0
# 1220   2020-01-28     USA          5        0.0       0
# 1396   2020-01-29     USA          5        0.0       0
# 1572   2020-01-30     USA          5        0.0       0
# 1748   2020-01-31     USA          7        0.0       0
# 1924   2020-02-01     USA          8        0.0       0
# 2100   2020-02-02     USA          8        0.0       0
# 2276   2020-02-03     USA         11        0.0       0
# 2452   2020-02-04     USA         11        0.0       0
# 2628   2020-02-05     USA         11        0.0       0
# 2804   2020-02-06     USA         11        0.0       0
# ...

# %%
df = data.sort_values(by=['Date'],ascending=False)

# %%
df.to_csv("countries-aggregated.csv",index=False)
